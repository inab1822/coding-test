# %% [markdown]
# ## 문제 설명
# - "명예의 전당"이라는 TV 프로그램에서는 매일 1명의 가수가 노래를 부르고, 시청자들의 문자 투표수로 가수에게 점수를 부여합니다. 매일 출연한 가수의 점수가 지금까지 출연 가수들의 점수 중 상위 k번째 이내이면 해당 가수의 점수를 명예의 전당이라는 목록에 올려 기념합니다. 즉 프로그램 시작 이후 초기에 k일까지는 모든 출연 가수의 점수가 명예의 전당에 오르게 됩니다. k일 다음부터는 출연 가수의 점수가 기존의 명예의 전당 목록의 k번째 순위의 가수 점수보다 더 높으면, 출연 가수의 점수가 명예의 전당에 오르게 되고 기존의 k번째 순위의 점수는 명예의 전당에서 내려오게 됩니다.
#
# - 이 프로그램에서는 매일 "명예의 전당"의 최하위 점수를 발표합니다. 예를 들어, k = 3이고, 7일 동안 진행된 가수의 점수가 `[10, 100, 20, 150, 1, 100, 200]`이라면, 명예의 전당에서 발표된 점수는 아래의 그림과 같이 `[10, 10, 10, 20, 20, 100, 100]`입니다.
#
# ![image.png](attachment:bcadf6c9-fa37-430f-9b98-4a1369cdeca7.png)
#
# - 명예의 전당 목록의 점수의 개수 k, 1일부터 마지막 날까지 출연한 가수들의 점수인 score가 주어졌을 때, 매일 발표된 명예의 전당의 최하위 점수를 return하는 solution 함수를 완성해주세요.

# %% [markdown]
# ## 제한사항
# - 3 ≤ k ≤ 100
# - 7 ≤ score의 길이 ≤ 1,000
#     - 0 ≤ score[i] ≤ 2,000

# %%
k = 3
score = [10, 100, 20, 150, 1, 100, 200]
# [10, 10, 10, 20, 20, 100, 100] 가 출력되어야 한다.
k1 = 4
score1 = [0, 300, 40, 300, 20, 70, 150, 50, 500, 1000]
# [0, 0, 0, 0, 20, 40, 70, 70, 150, 300]가 출력되어야 한다.

# %%
def solution(k, score):
    
    # 정답을 넣을 answer리스트를 만든다.
    answer = []
    
    # score의 길이만큼 반복을 시작한다.
    for i in range(len(score)):
        # score의 처음부터 i번째까지 sorted로 정렬하여 rank에 할당한다.
        # 이때 reverse=True를 하면 내림차순으로 정렬된다.
        rank = sorted(score[0:i+1],reverse=True)
        
        # 만약 i가 k보다 같거나 크다면 rank에는 k보다 큰 개수의 요소가 들어가 있다.
        if i >= k:
            # 이때 우리는 k번째 요소를 원한다.
            # rank[k-1]로 k번째 요소를 answer에 마지막요소로 집어넣는다.
            answer.append(rank[k-1])
        # 만약 아니라면 즉, i가 k보다 작다면 rank에는 k개수 이하의 요소가 들어가 있다.
        else:
            # k번째 요소를 원하는데 k보다 갯수가 작기 때문에 그냥 제일 작은 값을
            # answer에 마지막 요소로 넣는다.
            answer.append(min(rank))
    return answer

# %%
print(solution(k, score))
print(solution(k1, score1))
# Out:
# [10, 10, 10, 20, 20, 100, 100]
# [0, 0, 0, 0, 20, 40, 70, 70, 150, 300]

# %% [markdown]
# ## 다른 사람의 풀이

# %%
k = 3
score = [10, 100, 20, 150, 1, 100, 200]
# [10, 10, 10, 20, 20, 100, 100] 가 출력되어야 한다.
k1 = 4
score1 = [0, 300, 40, 300, 20, 70, 150, 50, 500, 1000]
# [0, 0, 0, 0, 20, 40, 70, 70, 150, 300]가 출력되어야 한다.

# %%
def solution(k, score):
    
    # 리스트 q를 만든다.
    q = []
    
    # 답을 넣을 answer를 만든다.
    answer = []
    
    # for문으로 score의 요소 하나하나를 사용한다.
    for s in score:
        
        # s를 q에 마지막 요소로 집어 넣는다.
        q.append(s)
        
        # 만약 q의 길이가 k보다 크다면
        if (len(q) > k):
            
            # 리스트q의 제일 작은 값을 q에서 제거한다.
            q.remove(min(q))
        # 위의 if문에 해당이 안되면
        # 그냥 q의 제일 작은 값을 answer에 마지막 요소로 집어 넣는다.
        answer.append(min(q))

    return answer

# %%
print(solution(k, score))
print(solution(k1, score1))
# Out:
# [10, 10, 10, 20, 20, 100, 100]
# [0, 0, 0, 0, 20, 40, 70, 70, 150, 300]
